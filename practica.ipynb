# %% [raw]
# import sys
# !{sys.executable} -m pip install matplotlib

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %%
df_idi = pd.read_excel("Reportes_Acumulados.xls",sheet_name='Sheet0', skiprows=1)

# %%
df_idi.head()
# Out:
#             FECHALECTURA  Altos De La Estancia  COLMAC  \
# 0  2022-06-01 00:00:00.0                   0.4     0.1
# 1  2022-06-02 00:00:00.0                   0.0     2.6
# 2  2022-06-03 00:00:00.0                  27.4    22.7
# 3  2022-06-04 00:00:00.0                  10.9    16.9
# 4  2022-06-05 00:00:00.0                  22.3    13.8
#
#    Casas Fiscales Artillería  Cerro Cazadores  Cerro Norte  \
# 0                        0.1              0.4          0.0
# 1                        0.0              1.0          1.4
# 2                       36.2             32.0         24.1
# 3                       30.0             11.3         23.9
# 4                       17.7              3.8         29.7
#
#    Colegio 21 Ángeles (IED)  Colegio Agustín Fernández (IE  \
# 0                       0.0                            0.3
# 1                       0.8                            0.8
# 2                      15.2                           18.3
# ...

# %%
df_idi['Total'] = df_idi.sum(axis=1)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18936\2972795224.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_idi['Total'] = df_idi.sum(axis=1)

# %%
df_idi.head()
# Out:
#             FECHALECTURA  Altos De La Estancia  COLMAC  \
# 0  2022-06-01 00:00:00.0                   0.4     0.1
# 1  2022-06-02 00:00:00.0                   0.0     2.6
# 2  2022-06-03 00:00:00.0                  27.4    22.7
# 3  2022-06-04 00:00:00.0                  10.9    16.9
# 4  2022-06-05 00:00:00.0                  22.3    13.8
#
#    Casas Fiscales Artillería  Cerro Cazadores  Cerro Norte  \
# 0                        0.1              0.4          0.0
# 1                        0.0              1.0          1.4
# 2                       36.2             32.0         24.1
# 3                       30.0             11.3         23.9
# 4                       17.7              3.8         29.7
#
#    Colegio 21 Ángeles (IED)  Colegio Agustín Fernández (IE  \
# 0                       0.0                            0.3
# 1                       0.8                            0.8
# 2                      15.2                           18.3
# ...

# %%
df_idi.head()
# Out:
#             FECHALECTURA  Altos De La Estancia  COLMAC  \
# 0  2022-06-01 00:00:00.0                   0.4     0.1
# 1  2022-06-02 00:00:00.0                   0.0     2.6
# 2  2022-06-03 00:00:00.0                  27.4    22.7
# 3  2022-06-04 00:00:00.0                  10.9    16.9
# 4  2022-06-05 00:00:00.0                  22.3    13.8
#
#    Casas Fiscales Artillería  Cerro Cazadores  Cerro Norte  \
# 0                        0.1              0.4          0.0
# 1                        0.0              1.0          1.4
# 2                       36.2             32.0         24.1
# 3                       30.0             11.3         23.9
# 4                       17.7              3.8         29.7
#
#    Colegio 21 Ángeles (IED)  Colegio Agustín Fernández (IE  \
# 0                       0.0                            0.3
# 1                       0.8                            0.8
# 2                      15.2                           18.3
# ...

# %%
df_idi.isnull().sum()
# Out:
# FECHALECTURA                 0
# Altos De La Estancia         0
# COLMAC                       0
# Casas Fiscales Artillería    0
# Cerro Cazadores              0
#                             ..
# San Francisco Qda. Limas     0
# UAN Circunvalar              0
# UAN Usme                     0
# Vitelma                      0
# Total                        0
# Length: 64, dtype: int64

# %%
df_idi.describe()
# Out:
#        Altos De La Estancia     COLMAC  Casas Fiscales Artillería  \
# count              7.000000   7.000000                   7.000000
# mean              10.142857   9.200000                  15.128571
# std               10.792568   8.630566                  14.203487
# min                0.000000   0.100000                   0.000000
# 25%                2.200000   2.450000                   3.050000
# 50%                6.000000   6.000000                  15.900000
# 75%               16.600000  15.350000                  23.850000
# max               27.400000  22.700000                  36.200000
#
#        Cerro Cazadores  Cerro Norte  Colegio 21 Ángeles (IED)  \
# count         7.000000     7.000000                  7.000000
# mean          7.800000    13.000000                  3.400000
# std          11.382882    12.408868                  5.627314
# min           0.100000     0.000000                  0.000000
# ...

# %%
df_idi.columns
# Out:
# Index(['FECHALECTURA', 'Altos De La Estancia', 'COLMAC',
#        'Casas Fiscales Artillería', 'Cerro Cazadores', 'Cerro Norte',
#        'Colegio 21 Ángeles (IED)', 'Colegio Agustín Fernández (IE',
#        'Colegio Alberto Lleras Camarg', 'Colegio Alemania Unificada',
#        'Colegio Antonio García (IED)', 'Colegio Carlo Federici(IED)',
#        'Colegio Carlos Pizarro (IED)', 'Colegio Ciudad De Villavicenc',
#        'Colegio Eduardo Umaña (IED)', 'Colegio El Manantial (IED)',
#        'Colegio El Tesoro De La Cumbr', 'Colegio Francisco Primero S.S',
#        'Colegio Friedrich Naumann (IE', 'Colegio Gabriel Garcia Márque',
#        'Colegio Gustavo Morales Moral', 'Colegio Gustavo Restrepo (IED',
#        'Colegio Inem Francisco De Pau', 'Colegio La Belleza (IED)',
#        'Colegio La Chucua (IED)', 'Colegio La Felicidad(IED)',
#        'Colegio Los Alpes (IED)', 'Colegio Los Pinos (IED)',
#        'Colegio Magdalena Ortega De N', 'Colegio Manuel Elkin Patarroy',
# ...

# %%
df_idi.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Columns: 64 entries, FECHALECTURA to Total
# dtypes: float64(63), object(1)
# memory usage: 3.6+ KB

# %%
df_idi.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
print(type(df_can.columns))
print(type(df_can.index))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
df_idi.columns.tolist()
# Out:
# ['FECHALECTURA',
#  'Altos De La Estancia',
#  'COLMAC',
#  'Casas Fiscales Artillería',
#  'Cerro Cazadores',
#  'Cerro Norte',
#  'Colegio 21 Ángeles (IED)',
#  'Colegio Agustín Fernández (IE',
#  'Colegio Alberto Lleras Camarg',
#  'Colegio Alemania Unificada',
#  'Colegio Antonio García (IED)',
#  'Colegio Carlo Federici(IED)',
#  'Colegio Carlos Pizarro (IED)',
#  'Colegio Ciudad De Villavicenc',
#  'Colegio Eduardo Umaña (IED)',
#  'Colegio El Manantial (IED)',
#  'Colegio El Tesoro De La Cumbr',
#  'Colegio Francisco Primero S.S',
#  'Colegio Friedrich Naumann (IE',
#  'Colegio Gabriel Garcia Márque',
#  'Colegio Gustavo Morales Moral',
#  'Colegio Gustavo Restrepo (IED',
#  'Colegio Inem Francisco De Pau',
#  'Colegio La Belleza (IED)',
#  'Colegio La Chucua (IED)',
#  'Colegio La Felicidad(IED)',
#  'Colegio Los Alpes (IED)',
#  'Colegio Los Pinos (IED)',
#  'Colegio Magdalena Ortega De N',
#  'Colegio Manuel Elkin Patarroy',
#  'Colegio Moralba Suroriental (',
# ...

# %%
df_idi.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
print(type(df_idi.columns.tolist()))
print(type(df_idi.index.tolist()))
# Out:
# <class 'list'>
# <class 'list'>

# %%
df_can.shape
# Out:
# (8, 63)

# %%
df_idi.isnull().sum()
# Out:
# FECHALECTURA                 0
# Altos De La Estancia         0
# COLMAC                       0
# Casas Fiscales Artillería    0
# Cerro Cazadores              0
#                             ..
# San Francisco Qda. Limas     0
# UAN Circunvalar              0
# UAN Usme                     0
# Vitelma                      0
# Total                        0
# Length: 64, dtype: int64

# %%
df_idi.COLMAC  # returns a series
# Out:
# 0     0.1
# 1     2.6
# 2    22.7
# 3    16.9
# 4    13.8
# 5     2.3
# 6     6.0
# Name: COLMAC, dtype: float64

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
filas = len(df_idi.index)
dia= list(map(str, range(1, filas+1)))
dia
df_idi["dia"] = dia

# %%
Colmac = df_idi[["dia","COLMAC", "Casas Fiscales Artillería"]]
Colmac= Colmac[0:filas-1]
Colmac

Colmac.plot(kind='line', x="dia", y= ["Casas Fiscales Artillería","COLMAC", "UAN Usme"] )
plt.title('Precipitacion')
plt.ylabel('mm')
plt.xlabel('dia')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [172], in <module>
#       2 Colmac= Colmac[0:filas-1]
#       3 Colmac
# ----> 5 Colmac.plot(kind='line', x="dia", y= ["Casas Fiscales Artillería","COLMAC", "UAN Usme"] )
#       6 plt.title('Precipitacion')
#       7 plt.ylabel('mm')
#
# File ~\anaconda3\envs\jcpt\lib\site-packages\pandas\plotting\_core.py:958, in PlotAccessor.__call__(self, *args, **kwargs)
#     955             pass
#     957 # don't overwrite
# --> 958 data = data[y].copy()
#     960 if isinstance(data, ABCSeries):
#     961     label_name = label_kw or y
#
# File ~\anaconda3\envs\jcpt\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...
